# %% [markdown]
# # Темы заданий
#
# - Выберите тему задания из списка ниже.
# - Создайте копию файла с шаблоном оформления задания - это будет ваш рабочий блокнот.
# - Переименуйте рабочий блокнот в соответствии с выбранной темой.
# - Скопируйте описание задания в заголовочный блок рабочего блокнота.
# - Выполните задание непосредственно в рабочем блокноте.
#
# ## 1. Выявление недостоверных новостей
#
# По адресу [https://www.kaggle.com/c/detecting-fake-news/data](https://www.kaggle.com/c/detecting-fake-news/data) находится набор данных с новостными статьями. Некоторые из них помечены как достоверные, другие — как недостоверные (фейковые). Используя этот набор данных, создайте модель машинного обучения, способную обнаруживать фейковые новости.
#
# ## 2. Выживание пассажиров Титаника
#
# По адресу [https://www.kaggle.com/c/titanic/data](https://www.kaggle.com/c/titanic/data) находится набор данных с информацией о пассажирах Титаника. Используйте методы машинного обучения, чтобы построить модель, предсказывающую, какие пассажиры выжили после кораблекрушения.
#
# ## 3. Классификация чистых и грязных тарелок по фото
#
# По адресу [https://www.kaggle.com/c/platesv2/data](https://www.kaggle.com/c/platesv2/data) находится набор данных с фотографиями чистых и грязных тарелок. Создайте модель машинного обучения, которая сможет различать их.
#
# ## 4. Предсказание отмены бронирования отеля
#
# По адресу [https://www.kaggle.com/datasets/jessemostipak/hotel-booking-demand](https://www.kaggle.com/datasets/jessemostipak/hotel-booking-demand) находится набор данных с информацией о бронировании отелей. Создайте модель машинного обучения, которая будет предсказывать, будет ли бронирование отменено.
#
# ## 5. Распознавание изображений фруктов и овощей
#
# По адресу [https://www.kaggle.com/datasets/moltean/fruits](https://www.kaggle.com/datasets/moltean/fruits) находится набор данных с изображениями фруктов и овощей. Выберите 5 различных классов изображений и создайте модель машинного обучения, которая сможет их различать.
#
# ## 6. Генерация аннотаций к изображениям
#
# По адресу [https://www.kaggle.com/datasets/hsankesara/flickr-image-dataset](https://www.kaggle.com/datasets/hsankesara/flickr-image-dataset) находится набор данных с изображениями и их текстовыми аннотациями. Используя этот набор данных, создайте модель машинного обучения, которая сможет генерировать аннотации к изображениям.
#
# ## 7. Предсказание качества вина по химическому составу
#
# По адресу [https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009](https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009) находится набор данных с химическими характеристиками красного вина. Используя методы машинного обучения, создайте модель, предсказывающую качество вина.
#
# ## 8. Предсказание наличия сердечных заболеваний по медицинским показателям
#
# По адресу [https://www.kaggle.com/datasets/ronakkantariya/heart-disease-uci](https://www.kaggle.com/datasets/ronakkantariya/heart-disease-uci) находится набор данных с медицинскими показателями пациентов. Создайте модель машинного обучения для предсказания наличия сердечных заболеваний.
#
# ## 9. Классификация риска сердечно-сосудистых заболеваний
#
# По адресу [https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset](https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset) находится набор данных с параметрами здоровья пациентов. Постройте модель для классификации риска сердечно-сосудистых заболеваний.
#
# ## 10. Классификация опухолей молочной железы
#
# По адресу [https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data](https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data) находится набор данных с характеристиками опухолей молочной железы. Создайте модель, способную классифицировать опухоли как доброкачественные или злокачественные.
#
# ## 11. Сегментация клиентов по их покупательскому поведению
#
# По адресу [https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis](https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis) находится набор данных о покупательском поведении клиентов. Используя методы машинного обучения, выполните сегментацию клиентов.
#
# ## 12. Предсказание времени выполнения заказа в интернет-магазине
#
# По адресу [https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce](https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce) находится набор данных о заказах интернет-магазина. Постройте модель для предсказания времени доставки заказа.
#
# ## 13. Классификация цветов ириса по их описанию
#
# По адресу [https://www.kaggle.com/datasets/uciml/iris](https://www.kaggle.com/datasets/uciml/iris) находится набор данных о цветах ириса. Используйте методы машинного обучения для классификации вида цветка.
#
# ## 14. Определение съедобности гриба по его характеристикам
#
# По адресу [https://www.kaggle.com/datasets/uciml/mushroom-classification](https://www.kaggle.com/datasets/uciml/mushroom-classification) находится набор данных с характеристиками грибов. Создайте модель, которая сможет определять, является ли гриб съедобным или ядовитым.
#
# ## 15. Предсказание оттока клиентов телеком-компании
#
# По адресу [https://www.kaggle.com/datasets/blastchar/telco-customer-churn](https://www.kaggle.com/datasets/blastchar/telco-customer-churn) находится набор данных о клиентах телеком-компании. Постройте модель для предсказания оттока клиентов.
#
# ## 16. Обнаружение мошеннических транзакций по банковским картам
#
# По адресу [https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud](https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud) находится набор данных с транзакциями по банковским картам, размеченными как мошеннические или обычные. Создайте модель для обнаружения мошеннических транзакций.
#
# ## 17. Классификация одежды по изображениям
#
# По адресу [https://www.kaggle.com/datasets/zalando-research/fashionmnist](https://www.kaggle.com/datasets/zalando-research/fashionmnist) находится набор изображений одежды. Используя сверточные нейронные сети, создайте модель классификации одежды.
#
# ## 18. Определение вида птиц по их изображеню
#
# По адресу [https://www.kaggle.com/datasets/kimberlym227/birds-km](https://www.kaggle.com/datasets/kimberlym227/birds-km) находится набор изображений птиц. Создайте CNN-модель, способную определять вид птицы.
#
# ## 19. Классификации видов цветов по их изображениями
#
# По адресу [https://www.kaggle.com/datasets/alxmamaev/flowers-recognition](https://www.kaggle.com/datasets/alxmamaev/flowers-recognition) находится набор изображений цветов. Постройте нейронную сеть для классификации видов цветов.
#
# ## 20. Классификация животных по их изображениям
#
# По адресу [https://www.kaggle.com/datasets/iamsouravbanerjee/animal-image-dataset-90-different-animals](https://www.kaggle.com/datasets/iamsouravbanerjee/animal-image-dataset-90-different-animals) находится набор изображений животных. Создайте модель, которая сможет классифицировать вид животного.
#
# ## 21. Модель распознавания именованных сущностей в тексте
#
# По адресу [https://www.kaggle.com/datasets/abhinavwalia95/entity-annotated-corpus](https://www.kaggle.com/datasets/abhinavwalia95/entity-annotated-corpus) находится набор текстов с размеченными именованными сущностями. Создайте модель распознавания именованных сущностей (NER).
#
# ## 22. Анализ тональности отзывов пользователей маркетплейса
#
# По адресу [https://www.kaggle.com/datasets/cynthiarempel/amazon-us-customer-reviews-dataset](https://www.kaggle.com/datasets/cynthiarempel/amazon-us-customer-reviews-dataset) находится набор текстовых отзывов пользователей Amazon. Используя нейронные сети, создайте модель анализа тональности отзывов.
#
# ## 23. Рекомендательная система система выбора фильма по его характеристикам
#
# По адресу [https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset](https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset) находится набор данных о фильмах. Создайте нейронную сеть для построения рекомендательной системы.
#
# ## 24. Классификация текстов на примере новостей о COVID-19
#
# По адресу [https://www.kaggle.com/datasets/datatattle/covid-19-nlp-text-classification](https://www.kaggle.com/datasets/datatattle/covid-19-nlp-text-classification) находится набор новостных текстов о COVID-19. Создайте модель классификации текстов.
#
# ## 25. Модель предсказания погоды
#
# По адресу [https://www.kaggle.com/datasets/nikhil7280/weather-type-classification](https://www.kaggle.com/datasets/nikhil7280/weather-type-classification) находится набор данных о погоде. Постройте нейронную сеть для предсказания типа погоды.
#
# ## 26. Модель обнаружения маски на изображении лица
#
# По адресу [https://www.kaggle.com/datasets/omkargurav/face-mask-dataset](https://www.kaggle.com/datasets/omkargurav/face-mask-dataset) находится набор изображений людей в масках и без масок. Создайте модель обнаружения масок на лице.
#
# ## 27. Анализ тональности отзывов об авиакомпаниях
#
# По адресу [https://www.kaggle.com/datasets/crowdflower/twitter-airline-sentiment](https://www.kaggle.com/datasets/crowdflower/twitter-airline-sentiment) находится набор твитов о крупных авиакомпаниях США. Постройте модель анализа тональности сообщений пользователей. Датасет содержит размеченные твиты с метками *positive*, *neutral* и *negative*.
#
# ## 28. Классификации типа поражения кожи по фото
#
# По адресу [https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000](https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000) находится набор дерматологических изображений различных типов кожных заболеваний. Создайте модель компьютерного зрения для классификации типа поражения кожи.
#
# ## 29. Обнаружение спама в СМС-сообщениях
#
# По адресу [https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset](https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset) находится набор SMS-сообщений, размеченных как спам или обычные сообщения. Используя методы NLP, создайте модель обнаружения спама.
#
# ## 30. Выявление наличия диабета по медицинским данным пациентов
#
# По адресу [https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database](https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database) находится набор медицинских данных пациентов. Создайте модель машинного обучения, которая сможет предсказывать наличие диабета у пациента.
