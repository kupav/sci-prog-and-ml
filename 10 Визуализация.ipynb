# %% [markdown]
# # Задания по теме «Визуализация математических данных» в Python
#
# Для выполнения приведённых ниже заданий предполагается использование библиотеки **Matplotlib**, прежде всего модуля `matplotlib.pyplot`, в **объектно-ориентированном стиле**:
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots()
# ax.plot(...)
# ax.set_title(...)
# ax.set_xlabel(...)
# ax.set_ylabel(...)
# ax.grid(True)
# plt.show()
# ```
#
# При необходимости допускается использование дополнительных библиотек, например `seaborn`.

# %% [markdown]
# ## Задание 1: Линейный график функции одной переменной
#
# Постройте графики функций
# $$
# y = \sin x, \qquad y = \cos x
# $$
# на отрезке $[0, 2\pi]$.
#
# Требуется:
# - создать массив значений $x$ из 400 точек;
# - вывести обе функции на одном поле;
# - добавить заголовок, подписи осей, легенду и сетку;
# - сделать линии различимыми по стилю.

# %% [markdown]
# ## Задание 2: Несколько подграфиков в одном окне
#
# Постройте в одном окне четыре графика функций:
# $$
# y = x, \quad y = x^2, \quad y = x^3, \quad y = |x|
# $$
# на отрезке $[-2, 2]$.
#
# Требуется:
# - использовать сетку подграфиков $2 \times 2$;
# - у каждого графика должен быть собственный заголовок;
# - у всех графиков должны быть включены сетки.

# %% [markdown]
# ## Задание 3: Параметрические кривые
#
# Постройте параметрическую кривую
# $$
# x(t) = \cos(3t), \qquad y(t) = \sin(2t), \qquad t \in [0, 2\pi].
# $$
#
# Требуется:
# - построить кривую Лиссажу;
# - установить одинаковый масштаб по осям;
# - добавить сетку и заголовок.

# %% [markdown]
# ## Задание 4: Точечная диаграмма
#
# Сгенерируйте выборку из 200 точек:
# - $x$ — случайные числа из стандартного нормального распределения;
# - $y = 2x + \epsilon$, где $\epsilon$ — малый шум с равномерным распределением.
#
# Постройте точечную диаграмму (`scatter plot`).
#
# Требуется:
# - визуально показать линейную зависимость;
# - подписать оси;
# - добавить полупрозрачность маркеров.

# %% [markdown]
# ## Задание 5: Столбчатая диаграмма для дискретных данных
#
# Пусть даны значения числа итераций, потребовавшихся разным численным методам для достижения заданной точности:
#
# | Метод | Число итераций |
# |-|-|
# | Метод бисекции | 24 |
# | Метод Ньютона | 6 |
# | Метод секущих | 8 |
# | Простая итерация | 31 |
#
# Постройте столбчатую диаграмму.
#
# Требуется:
# - подписать категории по оси $x$;
# - добавить подписи значений над столбцами;
# - повернуть подписи, если это нужно для читаемости.

# %% [markdown]
# ## Задание 6: Гистограмма распределения
#
# Сгенерируйте 1000 случайных чисел из нормального распределения с математическим ожиданием 0 и стандартным отклонением 1. Постройте гистограмму.
#
# Требуется:
# - выбрать разумное число столбцов;
# - отобразить плотность распределения (`density=True`);
# - поверх гистограммы нанести теоретическую кривую плотности нормального распределения.

# %% [markdown]
# ## Задание 7: Визуализация погрешности численного метода
#
# Предположим, что погрешность аппроксимации производной имеет вид
# $$
# E(h) = h + \frac{10^{-8}}{h}.
# $$
# Для значений
# $$
# h = 10^{-1}, 10^{-2}, 10^{-3}, 10^{-4}, 10^{-5}
# $$
# постройте график зависимости ошибки от шага.
#
# Требуется:
# - использовать логарифмический масштаб по обеим осям;
# - отметить точку минимума ошибки;

# %% [markdown]
# ## Задание 8: Контурный график функции двух переменных
#
# Постройте линии уровня функции
# $$
# f(x, y) = x^2 + y^2
# $$
# на квадрате $[-2, 2] \times [-2, 2]$.
#
# Требуется:
# - создать двумерную сетку с помощью `np.meshgrid`;
# - построить контурный график (`contour`);
# - подписать линии уровня.

# %% [markdown]
# ## Задание 9: Тепловая карта матрицы
#
# Сгенерируйте матрицу размера `10 x 10`, элементы которой задаются формулой
# $$
# a_{ij} = \sin(i)\cos(j).
# $$
# Постройте тепловую карту этой матрицы.
#
# Требуется:
# - использовать `imshow`;
# - добавить цветовую шкалу;
# - подписать заголовок рисунка.

# %% [markdown]
# ## Задание 10: Визуализация матрицы и её спектра
#
# Сгенерируйте случайную симметричную матрицу размера `8 x 8` и найдите её собственные числа. Постройте:
# - слева — тепловую карту матрицы;
# - справа — столбчатую диаграмму её собственных чисел.
#
# Требуется:
# - использовать `np.linalg.eigvalsh`;
# - расположить графики рядом;
# - подписать оси и заголовки.

# %% [markdown]
# ## Задание 11: Трёхмерная поверхность
#
# Постройте поверхность функции
# $$
# z = \sin\bigl(\sqrt{x^2 + y^2}\bigr)
# $$
# на квадрате $[-6, 6] \times [-6, 6]$.
#
# Требуется:
# - использовать трёхмерные оси;
# - подписать оси $x$, $y$, $z$;
# - подобрать число точек сетки так, чтобы поверхность была достаточно гладкой.

# %% [markdown]
# ## Задание 12: Векторное поле
#
# Рассмотрите векторное поле
# $$
# \vec{F}(x, y) = (-y, x).
# $$
# Постройте его на квадрате $[-2, 2] \times [-2, 2]$.
#
# Требуется:
# - использовать `quiver`;
# - отобразить направление вращения поля;
# - установить одинаковый масштаб по осям.

# %% [markdown]
# ## Задание 13. Анимация графика функции в Jupyter
#
# Используя анимацию, покажите как меняется график функции
# $$
# y = \sin(x + \varphi)
# $$
# при изменении параметра $\varphi$.
#
# Для отображения анимации в среде Jupyter или Colab используйте `FuncAnimation` из модуля `matplotlib.animation`. В некоторых случаях, если анимация не отображается, помогает в начале ноутбука  выполнить одну из команд.
# ```python
# %matplotlib inline
# ```
# или
# ```python
# %matplotlib notebook
# ```
# Однако в среде Colab это не потребуется.
#
# Требуется:
# - создать фигуру и оси в объектно-ориентированном стиле;
# - создать объект линии один раз;
# - описать функцию обновления кадра;
# - построить анимацию с помощью `FuncAnimation`;
# - вывести анимацию в Jupyter через `HTML(anim.to_jshtml())`.

# %% [markdown]
# ## Задание 14: Оформление графика: аннотации, выделение точек, диапазонов
#
# Для функции
# $$
# y = x^3 - 3x
# $$
# на отрезке $[-2.5, 2.5]$ постройте график и визуально выделите:
# - точки локального максимума и минимума;
# - интервал, на котором функция возрастает.
#
# Требуется:
# - найти критические точки аналитически или вручную использовать известные значения;
# - подписать экстремумы с помощью `ax.annotate`;
# - выделить интервал цветовой заливкой.

# %% [markdown]
# ## Задание 15: Сравнение нескольких наборов данных на одном рисунке
#
# Пусть имеются три последовательности ошибок численного метода в зависимости от номера итерации:
# $$
# e_k^{(1)}, \quad e_k^{(2)}, \quad e_k^{(3)}.
# $$
# Смоделируйте три убывающие последовательности и постройте их на одном графике. Формулы для убывающих последовательностей подберите самостоятельно.
#
# Требуется:
# - использовать разные маркеры и стили линий;
# - по оси $y$ использовать логарифмический масштаб;
# - добавить легенду и сетку.

# %% [markdown]
# ## Задание 16: Оформление оси в долях числа $\pi$
#
# Постройте график функции
# $$
# y = \sin x
# $$
# на отрезке $[0, 2\pi]$.
#
# Требуется:
# - построить график в объектно-ориентированном стиле `matplotlib`;
# - подписать деления по оси $x$ не числами, а выражениями вида
#   $$
#   0,\; \frac{\pi}{4},\; \frac{\pi}{2},\; \frac{3\pi}{4},\; \pi,\; \ldots,\; 2\pi;
#   $$
# - добавить заголовок, подписи осей и сетку.
