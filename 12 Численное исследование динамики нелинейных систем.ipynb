# %% [markdown]
# # Практические задания по теме «Численное исследование динамики нелинейных систем»
#
# В заданиях ниже рассматриваются два класса динамических систем:
# - системы с дискретным временем, задаваемые рекуррентными отображениями;
# - потоковые системы, задаваемые системами обыкновенных дифференциальных уравнений.
#
# Для численного решения ОДУ используйте `scipy.integrate.solve_ivp`. Во всех заданиях старайтесь не только получить рисунок, но и интерпретировать его: определить стационарные режимы, периодические колебания, квазипериодичность, хаотические режимы, области мультистабильности.
#
# Во многих заданиях полезно использовать следующие импорты:
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.integrate import solve_ivp
# ```
#
# **Изучите внимательно следующие рекомендации**
#
# 1. При исследовании бифуркаций и показателей Ляпунова важно выбирать достаточно длинный переходный процесс.
# 2. Для построения карт режимов нужно аккуратно подбирать критерий определения периода; при слишком грубом критерии возможны ошибки классификации.
# 3. Для идентификации хаотических режимов полезно сравнивать несколько характеристик сразу: временные зависимости, фазовые портреты, сечения Пуанкаре, бифуркационные диаграммы, показатели Ляпунова.
# 4. Если расчёт получается слишком долгим, уменьшите число точек в сетке параметров, а затем постепенно увеличивайте его.
# 5. При использовании `solve_ivp` для построения сечения Пуанкаре удобно ограничивать `max_step`, чтобы событие не «перепрыгивалось» слишком крупным шагом интегрирования.

# %% [markdown]
# ## Задание 1: Итерации логистического отображения и график зависимости от номера итерации
#
# Рассмотрите логистическое отображение
# $$
#  x_{n+1} = r x_n (1 - x_n).
# $$
#
# Возьмите параметры `r = 3.2`, `x0 = 0.2`, число итераций `N = 100`.
#
# 1. Вычислите последовательность $x_n$.
# 2. Постройте график зависимости $x_n$ от номера итерации $n$.
# 3. По графику определите, стремится ли система к неподвижной точке, циклу или демонстрирует более сложное поведение.

# %% [markdown]
# ## Задание 2: Диаграмма Ламерея для дискретного отображения
#
# Для логистического отображения
# $$
# x_{n+1} = r x_n (1 - x_n)
# $$
# при `r = 3.5` постройте диаграмму Ламерея (cobweb plot, паутинная диаграмма).
#
# 1. Постройте графики функций $y = f(x)$ и $y = x$.
# 2. Для начального условия `x0 = 0.15` изобразите последовательность переходов $(x_n, x_{n+1})$.
# 3. Объясните, как по паутинной диаграмме можно понять характер асимптотического режима.

# %% [markdown]
# ## Задание 3: Бифуркационная диаграмма логистического отображения
#
# Постройте бифуркационную диаграмму логистического отображения при изменении параметра $r$ в диапазоне от `2.5` до `4.0`.
#
# 1. Для каждого значения параметра выполните достаточно длинную серию итераций.
# 2. Отбросьте переходный процесс.
# 3. Нанесите на плоскость точки $(r, x_n)$ для последних итераций.
# 4. Найдите области неподвижной точки, периодических циклов и хаоса.

# %% [markdown]
# ## Задание 4: Показатель Ляпунова для дискретного отображения
#
# Для логистического отображения вычислите старший показатель Ляпунова как функцию параметра $r$:
# $$
# \lambda = \lim_{N\to\infty} \frac{1}{N} \sum_{n=0}^{N-1} \ln |f'(x_n)|,
# $$
# где
# $$
# f'(x) = r(1-2x).
# $$
#
# 1. Постройте график $\lambda(r)$.
# 2. Сравните его с бифуркационной диаграммой.
# 3. Укажите области, где $\lambda < 0$, $\lambda = 0$ и $\lambda > 0$.

# %% [markdown]
# ## Задание 5: Карта режимов на плоскости параметров для дискретной системы
#
# Рассмотрите отображение круга
# $$
# \theta_{n+1} = \theta_n + \Omega - \frac{K}{2\pi}\sin(2\pi \theta_n) \pmod 1.
# $$
#
# Постройте карту режимов на плоскости параметров $(\Omega, K)$.
#
# 1. Для каждой точки параметров вычислите траекторию.
# 2. Попытайтесь определить период режима по последним итерациям.
# 3. Закодируйте цветом найденный период: например, период 1, 2, 3, 4, 5, а всё более сложное поведение объедините в один класс.
# 4. Обратите внимание на языки Арнольда.

# %% [markdown]
# ## Задание 6: Двумерное отображение Эно и фазовый портрет
#
# Рассмотрите отображение Эно:
# $$
# \begin{cases}
#  x_{n+1} = 1 - a x_n^2 + y_n, \\
#  y_{n+1} = b x_n.
# \end{cases}
# $$
#
# Возьмите `a = 1.4`, `b = 0.3`.
#
# 1. Вычислите траекторию длины не менее 10000 шагов.
# 2. Отбросьте начальный переходный участок.
# 3. Постройте фазовый портрет на плоскости $(x, y)$.
# 4. Охарактеризуйте полученное множество.

# %% [markdown]
# ## Задание 7: Решение автономной системы ОДУ и временные зависимости
#
# Рассмотрите систему Лотки–Вольтерры:
# $$
# \begin{cases}
# \dot x = \alpha x - \beta x y, \\
# \dot y = \delta x y - \gamma y.
# \end{cases}
# $$
#
# Возьмите параметры `alpha = 1.5`, `beta = 1.0`, `delta = 0.75`, `gamma = 1.0`.
#
# 1. Решите задачу Коши с начальными условиями `x(0)=2`, `y(0)=1` на интервале `t in [0, 30]`.
# 2. Постройте графики $x(t)$ и $y(t)$.
# 3. Проанализируйте характер колебаний.

# %% [markdown]
# ## Задание 8: Фазовый портрет потоковой системы
#
# Для той же системы Лотки–Вольтерры постройте фазовый портрет.
#
# 1. Изобразите траекторию на плоскости $(x, y)$.
# 2. Постройте несколько траекторий для разных начальных условий.
# 3. Найдите стационарную точку и отметьте её на графике.

# %% [markdown]
# ## Задание 9: Фазовый портрет и временные зависимости для осциллятора Ван дер Поля
#
# Рассмотрите уравнение Ван дер Поля в виде системы:
# $$
# \begin{cases}
# \dot x = y, \\
# \dot y = \mu (1 - x^2)y - x.
# \end{cases}
# $$
#
# Возьмите `mu = 3`.
#
# 1. Постройте график $x(t)$.
# 2. Постройте фазовый портрет $(x, y)$.
# 3. Покажите, что траектория выходит на предельный цикл.

# %% [markdown]
# ## Задание 10: Сечение Пуанкаре для системы Рёсслера с использованием `events`
#
# Рассмотрите систему Рёсслера:
# $$
# \begin{cases}
# \dot x = -y - z, \\
# \dot y = x + a y, \\
# \dot z = b + z(x-c).
# \end{cases}
# $$
#
# Возьмите `a = 0.2`, `b = 0.2`, `c = 5.7`.
#
# 1. Решите систему на большом интервале времени.
# 2. Используя параметр `events` функции `solve_ivp`, зарегистрируйте моменты пересечения плоскости $x = 0$ в направлении `dx/dt > 0`.
# 3. Постройте отображение сечения Пуанкаре на плоскости $(y, z)$.

# %% [markdown]
# ## Задание 11: Стробоскопическое сечение для неавтономной системы
#
# Рассмотрите неавтономный осциллятор Дуффинга:
# $$
# \ddot x + \delta \dot x - x + x^3 = \gamma \cos(\omega t).
# $$
#
# Перепишите его в виде системы первого порядка. Возьмите параметры
# `delta = 0.2`, `gamma = 0.3`, `omega = 1.2`.
#
# 1. Решите систему на большом интервале времени.
# 2. Постройте фазовую траекторию.
# 3. Постройте стробоскопическое сечение, отмечая точки через период внешнего воздействия
# $$
# T = \frac{2\pi}{\omega}.
# $$

# %% [markdown]
# ## Задание 12: Бифуркационная диаграмма неавтономного осциллятора
#
# Для неавтономного осциллятора Дуффинга постройте бифуркационную диаграмму по параметру амплитуды внешней силы `gamma`.
#
# 1. Для каждого значения `gamma` численно решите систему.
# 2. Используйте стробоскопическое сечение через период внешнего воздействия.
# 3. После удаления переходного процесса нанесите на график пары $(\gamma, x_n)$, где $x_n$ — значения в стробоскопические моменты.

# %% [markdown]
# ## Задание 13: Карта режимов для неавтономного осциллятора на плоскости параметров
#
# Для неавтономного осциллятора Дуффинга постройте карту режимов на плоскости параметров `(gamma, omega)`.
#
# 1. Для каждой точки параметров вычислите стробоскопическую последовательность.
# 2. Определите период режима по последним точкам.
# 3. Постройте цветовую карту периодов.
# 4. Найдите области периодических и хаотических режимов.

# %% [markdown]
# ## Задание 14: Вычисление старшего показателя Ляпунова для потоковой системы
#
# Рассмотрите систему Лоренца:
# $$
# \begin{cases}
# \dot x = \sigma (y - x), \\
# \dot y = x(\rho - z) - y, \\
# \dot z = xy - \beta z.
# \end{cases}
# $$
#
# Возьмите `sigma = 10`, `beta = 8/3`, `rho = 28`.
#
# Вычислите старший показатель Ляпунова методом двух близких траекторий.
#
# 1. Возьмите две очень близкие начальные точки.
# 2. Интегрируйте систему на малом временном шаге.
# 3. После каждого шага перенормируйте расстояние между траекториями до исходного малого значения.
# 4. Усредните логарифм коэффициента растяжения.

# %% [markdown]
# ## Задание 15: График старшего показателя Ляпунова в зависимости от параметра
#
# Для системы Лоренца постройте зависимость старшего показателя Ляпунова от параметра `rho`.
#
# 1. Зафиксируйте `sigma = 10`, `beta = 8/3`.
# 2. Просканируйте значения `rho` в некотором диапазоне, например от `0` до `100`.
# 3. Для каждого `rho` вычислите показатель Ляпунова методом двух близких траекторий.
# 4. Постройте график $\lambda(\rho)$.

# %% [markdown]
# ## Задание 16: Сравнение нескольких режимов одной системы при разных параметрах
#
# Выберите одну из рассмотренных выше систем:
# - логистическое отображение;
# - отображение Эно;
# - осциллятор Дуффинга;
# - система Лоренца;
# - система Рёсслера.
#
# Проведите небольшое численное исследование:
# 1. выберите не менее трёх значений параметра;
# 2. для каждого параметра постройте временной график или последовательность итераций;
# 3. постройте фазовый портрет или соответствующее сечение;
# 4. укажите, как изменяется тип режима при изменении параметра.
