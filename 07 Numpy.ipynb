# %% [markdown]
# # Задания по использованию модуля numpy

# %% [markdown]
# ## Задание 1: Создание массива и его атрибуты
# Дан список чисел `[1, 2, 3, 4, 5, 6]`. Создайте на его основе numpy-массив. Выведите на экран:
# - размерность (`ndim`),
# - форму (`shape`),
# - общее количество элементов (`size`),
# - тип данных (`dtype`).

# %% [markdown]
# ## Задание 2: Отличие numpy-массива от списка
# Создайте список `[1, 2, 3]` и numpy-массив из тех же чисел. Умножьте каждый из них на 2 и выведите результаты. Объясните разницу.
#
# Создайте списки `[3, 2, 'a', 1]` и `[3, 2, 1, 3.14]`. Теперь создайте на их основе numpy-массивы. Напечатайте эти массивы, а также типы их элементов при помощи `dtype`. Найдите самостоятельно описание того, что выводит эта функция. Объясните получившийся результат.

# %% [markdown]
# ## Задание 3: Типы данных в массивах
# Создайте массив целых чисел `[1, 2, 3]`. Последовательно преобразуйте его в типы `float64` и `complex128`, каждый раз выводя массив и его `dtype`. Найдите самостоятельно описания этих типов.

# %% [markdown]
# ## Задание 4: Изменение типа данных с помощью `astype`
# Дан массив дробных чисел `[1.7, 2.4, -3.9]`. Преобразуйте его в целочисленный тип `int32` и в булев тип `bool`. Выведите результаты и объясните, что произошло при преобразовании.

# %% [markdown]
# ## Задание 5: Специальные массивы и like-функции
# 1. Создайте:
#    - массив из нулей размером 3×4,
#    - массив из единиц размером 2×3×2,
#    - массив размером 2×2, заполненный числом 5.5,
#    - пустой массив размером 3×3.
# 2. Пусть дан массив `a = np.array([[1, 2], [3, 4]])`. Создайте с помощью `like-функций` массив из нулей такой же формы, как `a`.
#
# Найдите ответы на вопросы:
# - В чём отличие пустого массива от массива нулей?
# - Что хранить пустой массив сразу после создания?
# - Какой из двух массивов создаётся быстрее?

# %% [markdown]
# ## Задание 6: Создание сеток: `arange`, `linspace`, `logspace`
# Сгенерируйте:
# - последовательность от 0 до 10 с шагом 0.5 (используя `arange`),
# - 5 равномерно распределённых чисел от 1 до 100 (используя `linspace`),
# - 5 чисел от $10^0$ до $10^3$ в логарифмическом масштабе (используя `logspace`).

# %% [markdown]
# ## Задание 7: Индексация и срезы. Представления (view) и копии
# Создайте двумерный массив 5×5, заполненный числами от 0 до 24 (используйте `reshape`).
# 1. Используя срезы (slices), извлеките и напечатайте
#     - первую строку,
#     - последний столбец,
#     - подмассив 2×3 из центра (строки 1–2, столбцы 2–4).
# 3. Измените элемент в последнем срезе (например, присвойте новое значение) и убедитесь, что исходный массив тоже изменился.
# 4. Создайте копию этого среза (метод `.copy()`) и покажите, что изменения в копии не затрагивают исходный массив.

# %% [markdown]
# ## Задание 8: Векторные операции вместо циклов
# Дан массив `[0, π/2, π, 3π/2, 2π]`. Вычислите для каждого элемента:
# - синус,
# - косинус,
# - экспоненту,
# - квадрат числа.
# Все вычисления выполните без циклов.

# %% [markdown]
# ## Задание 9: Сравнение скорости цикла `for` и векторизованной операции
# Создайте массив из 1 миллиона элементов (например, с помощью `np.arange(1e6)`). Вычислите сумму квадратов элементов двумя способами:
# - с помощью цикла `for` по элементам,
# - с помощью векторизованной операции `np.sum(arr**2)`.
# Замерьте и сравните время выполнения (например, используйте `time.time()`). Объясните, что произойдет, если массив будет содержать 10 миллионов элементов?

# %% [markdown]
# ## Задание 10: Оси и агрегатные функции: сумма, произведение, среднее, дисперсия, стандартное отклонение
# Создайте двумерный массив из 5 строк и 8 столбцов, содержащий числа от 1 до 40 (используйте `arange` и `reshape`).
#
# Напечатайте этот массив, а затем вычислите, используй только агрегатные функции, без применения циклов:
# - сумму элементов в каждой строке
# - среднее для элементов в каждом столбце
# - дисперсию элементов на главной диагонали
# - стандартное отклонение всех элементов
# - произведение элементов 6-й над-диагонали

# %% [markdown]
# ## Задание 11: Объединение массивов: `concatenate`, `vstack`, `hstack`
# Создайте два двумерных массива размером 2×2:
# `a = [[1, 2], [3, 4]]`
# `b = [[5, 6], [7, 8]]`
# 1. Объедините их вертикально (по строкам) с помощью `vstack` или `concatenate`.
# 2. Объедините их горизонтально (по столбцам) с помощью `hstack` или `concatenate`.
# 3. Создайте два одномерных массива `x = [1, 2, 3]` и `y = [4, 5, 6]`. Объедините их в двумерный массив: сначала как строки (стек по строкам), затем как столбцы (стек по столбцам).

# %% [markdown]
# ## Задание 12: Разделение массивов: `split`, `vsplit`, `hsplit`
# 1. Создайте одномерный массив из 12 элементов (0..11). Разделите его на 3 равные части с помощью `np.split`.
# 2. Создайте двумерный массив 4×4 (0..15). Разделите его:
#    - на 2 части по вертикали (по строкам) с помощью `vsplit`,
#    - на 2 части по горизонтали (по столбцам) с помощью `hsplit`.

# %% [markdown]
# ## Задание 13: Добавление и удаление осей
# Дан одномерный массив `[1, 2, 3, 4, 5]`.
# 1. Превратите его в вектор-столбец (форма (5,1)) с помощью `np.newaxis` или `np.expand_dims`.
# 2. Превратите его в вектор-строку (форма (1,5)).
# 3. Создайте трёхмерный массив с осями длины 1 (например, (1,5,1)) с помощью добавления осей, а затем удалите все оси размерности 1 с помощью `np.squeeze`.

# %% [markdown]
# ## Задание 14: Изменение формы: `reshape`, `ravel`, `flatten`
# Создайте одномерный массив из 24 элементов (например, от 0 до 23).
# 1. Преобразуйте его в матрицы размером (2,12), (3,8), (4,6), (2,3,4) с помощью `reshape`.
# 2. Сгладьте полученный трёхмерный массив обратно в одномерный с помощью `ravel` и `flatten`.
# 3. Измените элемент в массиве, полученном через `ravel`, и проверьте, изменится ли исходный. Проделайте то же с `flatten`.

# %% [markdown]
# ## Задание 15: Транспонирование массивов
# 1. Создайте матрицу 3×4 (например, от 1 до 12). Выполните её транспонирование (`.T`).
# 2. Создайте трёхмерный массив размером (2,3,4). Выполните его транспонирование с перестановкой осей в порядок (1,0,2). Выведите форму до и после.

# %% [markdown]
# ## Задание 16: Работа с комплексными числами
# Пусть даны два массива: действительные части `[1, 2, 3]` и мнимые части `[4, 5, 6]`. Создайте массив комплексных чисел. Извлеките из него:
# - действительную часть,
# - мнимую часть,
# - модуль,
# - фазу (угол).
# Также выполните сложение полученного массива с самим собой.

# %% [markdown]
# ## Задание 17. Извлечение корней из комплексных чисел
# Число `-8` имеет три кубических корня. С помощью Numpy найдите **все
# три** корня, используя формулу:
#
# $$
# z_k = |a|^{1/n} \cdot e^{i(\frac{\arg(a) + 2\pi k}{n})}, \quad k = 0, 1, \dots, n-1
# $$
#
# Убедитесь, что при возведении каждого корня в куб получается исходное
# число.
# Обратите внимание: функция `np.power` возвращает только главное
# значение; чтобы получить все корни, нужно применить формулу
# самостоятельно, но все вычисления можно выполнить векторизованно, без
# циклов.

# %% [markdown]
# ## Задание 18: Функции округления
# Создайте массив из чисел `[1.234, 2.678, -3.123, -4.567]`. Примените к нему:
# - округление вниз (`np.floor`),
# - округление вверх (`np.ceil`).
# - округление до ближайшего целого (`np.round`),
# - округление до двух знаков после запятой,

# %% [markdown]
# ## Задание 19: Механизм broadcasting
# 1. Создайте матрицу `A` размером 3×3 (например, от 1 до 9) и вектор `v` длиной 3 (например, [10, 20, 30]). Прибавьте вектор к каждой строке матрицы (используя broadcasting).
# 2. Попытайтесь прибавить к матрице 3×3 вектор длины 2. Объясните причину ошибки.

# %% [markdown]
# ## Задание 20: Логические операции над массивами
# Даны два массива:
# ```python
# a = np.array([1, 5, 3, 8, 2])
# b = np.array([2, 5, 1, 8, 0])
# ```
# 1. Выполните поэлементное сравнение `a > b`, `a == b`. Выведите полученные маски.
# 2. Проверьте с помощью `np.all`, все ли элементы `a` больше соответствующих элементов `b`.
# 3. Проверьте с помощью `np.any`, есть ли равные элементы в позициях.

# %% [markdown]
# ## Задание 21: Булевы маски и fancy indexing
# Дан массив `[-5, 3, 0, 7, -2, 8, -1]`.
# 1. С помощью булевой маски выберите все положительные элементы.
# 2. Замените все отрицательные элементы на 0.
# 3. С помощью списка индексов `[1, 3, 5]` выберите элементы на соответствующих позициях.
# 4. Попробуйте изменить выбранные через fancy indexing элементы и убедитесь, что исходный массив не меняется - мы имеем дело с копией, а не с представлением.

# %% [markdown]
# ## Задание 22: Сохранение и загрузка в бинарных форматах `.npy` и `.npz`
# Создайте два массива: `a = np.arange(10)`, `b = np.ones((3,3))`.
# 1. Сохраните массив `a` в файл `array.npy`.
# 2. Сохраните оба массива в один файл `arrays.npz` (под именами 'first' и 'second').
# 3. Загрузите массив из `array.npy` и убедитесь, что он совпадает с исходным.
# 4. Загрузите данные из `arrays.npz` и выведите оба массива.

# %% [markdown]
# ## Задание 23: Чтение и запись текстовых файлов
# Создайте двумерный массив 3×4, например, от 10 до 21 (reshape).
# 1. Сохраните его в текстовый файл `matrix.txt` с разделителем-запятой и форматом вывода целых чисел.
# 2. Прочитайте файл обратно с помощью `np.loadtxt` и убедитесь, что данные восстановлены верно.
# 3. Для одномерного массива `[1.234, 2.345, 3.456]` сохраните его в файл с 2 знаками после запятой, затем прочитайте.
